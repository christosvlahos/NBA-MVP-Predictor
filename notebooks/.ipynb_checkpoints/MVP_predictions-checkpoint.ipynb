# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib.pyplot as plt
import plotly.express as plex
import seaborn as sns
import tensorflow as tf

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.feature_selection import mutual_info_regression
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from tensorflow import keras

import warnings
from pandas.core.common import SettingWithCopyWarning
warnings.simplefilter(action = 'ignore', category=SettingWithCopyWarning)

from Model_functions import *

pd.set_option('display.max_columns', None, 'display.max.rows', None)
# Out:
# 2022-09-11 14:14:27.677571: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from sklearn.neural_network import MLPRegressor

# %%
#Read the csv file created in Data_processing notebook with the full dataset
#on per game stats from 1980 till 2022

per_game_data = pd.read_csv("data/MVP_per_game.csv")
per_poss_data = pd.read_csv("data/MVP_per_possession.csv")

#List of years we have data
years = [year for year in range(1980, 2022)]

# %%
#correlations between all features
corr_matrix_pg_spear = per_game_data.corr(method='spearman')


# Getting the Upper Triangle of the co-relation matrix
mask = np.triu(corr_matrix_pg_spear)

# using the upper triangle matrix as mask
fig, ax = plt.subplots(figsize=(15, 15))

sns.heatmap(corr_matrix_pg_spear,
            annot=False,
            mask=mask,
            square = True,
            cmap = "RdYlGn",
            ax = ax
           )


# #plot heat map
# mask = np.zeros_like(corr_matrix_spear)
# mask[np.triu_indices_from(mask)] = True
# with sns.axes_style("white"):
#     f, ax = plt.subplots(figsize=(15, 15))
#     ax = sns.heatmap(corr_matrix_spear, mask=mask, square=True, cmap="RdYlGn")
# Out:
# <AxesSubplot:>

# %%
#Pandas series with the correlation pairs
corr_pairs_pg_spear = corr_matrix_pg_spear.unstack().sort_values(kind = 'quicksort')


#Isolate the features with big correlations
large_corr_pg = corr_pairs_pg_spear[(np.abs(corr_pairs_pg_spear) > 0.83) &
                                    (np.abs(corr_pairs_pg_spear) != 1)
                                   ].drop_duplicates()

# %%
large_corr_pg
# Out:
# WS       WS/48    0.834517
# ORB%     TRB%     0.834926
# PER      WS/48    0.835124
# BPM      PER      0.835967
#          WS/48    0.838293
# OBPM     BPM      0.854805
# VORP     WS       0.864868
# USG%     PTS      0.867328
# OWS      WS       0.871191
# VORP     BPM      0.909089
# W        W/L%     0.929481
# TRB%     DRB      0.941276
# TRB      DRB%     0.943906
#          DRB      0.963487
# DRB%     TRB%     0.964094
# STL      STL%     0.974046
# DRB      DRB%     0.975405
# AST%     AST      0.977121
# TRB      TRB%     0.977668
# BLK%     BLK      0.981116
# ORB%     ORB      0.985289
# Pts Won  Share    0.992629
# dtype: float64

# %%
#Split data to historical (all but last year's data) and final year data.  

test_year = 2022

historical_data_pg = per_game_data[per_game_data["Year"] != test_year]
final_year_data_pg = per_game_data[per_game_data["Year"] == test_year]

# %%
#Dropping some initial columns

#Columns that are related to the target value but are not needed
pts_to_drop = ['First', 'Pts Won', 'Pts Max']

#Columns highly correlated to more advnced features we decide on keeping
cols_to_drop_pg_init = ["TRB", "DRB", "ORB", "AST", "STL", "BLK", "W", "WS"]


#Remove above columns from both historical and final_year datasets
historical_data_pg = historical_data_pg.drop(pts_to_drop+cols_to_drop_pg_init, axis=1)
final_year_data_pg = final_year_data_pg.drop(pts_to_drop+cols_to_drop_pg_init, axis=1)

# %%
#Features to drop for feature selection. They are not permanently removed.
drop_feat_selection = ['Player','Year', 'Age', 'Rank', 'Tm']

#Dataset used for feature selection
data_for_feature_selection_pg = historical_data_pg.drop(drop_feat_selection, axis=1)

# %%
scores_test_pg = feature_importance(data_for_feature_selection_pg)

# %%
plot_scores(scores_test_pg,
            figsize=(14,11),
            title = 'Mutual Information Scores'
           )

# %%
# MVP_races_data = per_game_data.copy()
# MVP_races_data['Result'] = np.where(MVP_races_data['Rank'] == '1', 'Yes', 'No')

# %%
# #plex.scatter(MVPs['VORP'], MVPs['Share'])
# fig1 = plex.scatter(MVP_races_data,
#                     x = 'Share',
#                     y = 'VORP',
#                     color='Result',
#                     hover_name='Player',
#                     hover_data=['Year']
#                    )

# fig1.show()

# %%
#Keep about half the features based on mutual infofrmation scores

feats_to_keep = 14
feats_pg, historical_data_pg_reduced = sort_features(data_for_feature_selection_pg,
                                               feats_to_keep,
                                               scores_test_pg
                                              )

# %%
#Splitting the datasets into identification (includes names, teams, ages etc)
#and game stats datasets keeping only the important features.

#For historical data
id_data_hist_pg = historical_data_pg[['Rank', 'Player', 'Age', 'Tm', 'Year', 'Share']]
full_historical_data_pg_reduced = id_data_hist_pg.join(historical_data_pg_reduced)


#For final_year data
id_data_pred_pg = final_year_data_pg[['Rank','Player', 'Age', 'Tm', 'Year', 'Share']]
data_pred_pg_reduced = final_year_data_pg[feats_pg]
full_prediction_data_pg_reduced = id_data_pred_pg.join(data_pred_pg_reduced)

#Share column is removed in split_per_one_year function
to_drop_train = ['Rank','Player', 'Age', 'Tm', 'Year']

# %%
def split_per_one_year(data, year, target = 'Share', scaling = False):
    
    '''
    Splits data into train and test datasets where test are the data for one year
    and rest is for training
    
    Args: 
        data: Dataframe for all years (historical data)
        year: Year that is used for test data
        target: Feature of data that will be the target for predictive algorithm -- default at Share
        scaling: Boolean to choose if we want the data to be scaled -- Default as False
        
    Returns:
        X_train: Training data without the actual values of target column
        Y_train: Labels of X_train
        X_test: Testing data without the actual values of target column
        Y_test: Labels of X_test
        
    '''
    
    to_drop_train = ['Rank','Player', 'Age', 'Tm', 'Year', 'Share']
    
    data2 = data.copy()
    
    train_data = data2[data2["Year"] != year]
    test_data = data2[data2["Year"] == year]
    
    Y_train = train_data[target]
    Y_test = test_data[target]
    
    print(Y_test.iloc[0])
    train_data_num = train_data.drop(to_drop_train, axis=1)
    test_data_num = test_data.drop(to_drop_train, axis=1)
    
    cols = train_data_num.columns.values
    
    if scaling == True:
        scaler = StandardScaler()
        train_array = scaler.fit_transform(train_data_num)
        train_data2 = pd.DataFrame(train_array, index=train_data_num.index, columns=cols)
        train_data.loc[:,cols] = train_data2[cols]
        test_array = scaler.transform(test_data_num)
        test_data2 = pd.DataFrame(test_array, index=test_data_num.index, columns=cols)
        test_data.loc[:,cols] = test_data2[cols]

    
    X_train = train_data.drop(target, axis=1)
    
    
    X_test = test_data.drop(target, axis=1)
    print(Y_test.iloc[0])
    
    return X_train, Y_train, X_test, Y_test

# %%
x1_train, y1_train, x1_test, y1_test = split_per_one_year(full_historical_data_pg_reduced, year=2000, scaling = True)
# Out:
# 0.998
# 0.998

# %%
from sklearn.linear_model import LinearRegression

x_train_all, y_train, x_test_all, y_test = data_prep(full_historical_data_pg_reduced,
                                             full_prediction_data_pg_reduced,
                                             feats_pg,
                                             scaling=True
                                            )

x_train = x_train_all.drop(['Rank', 'Player', 'Tm', 'Year', 'Age'], axis=1)
x_test = x_test_all.drop(['Rank', 'Player', 'Tm', 'Year', 'Age'], axis=1)

linear = LinearRegression()
linear.fit(x_train, y_train)

rank = x_test_all['Rank'].tolist()
names = x_test_all['Player'].tolist()
preds_ln = linear.predict(x_test)
preds_ln = preds_ln.tolist()
y_test_lst = y_test.tolist()
print("Mean squared error: %.3f" % mean_squared_error(y_test_lst, preds_ln))
print('R2 score: %.3f' % r2_score(y_test_lst, preds_ln))

ds_pred_ln = {'Actual Rank': rank,
                 'Player': names,
                 'Actual Share': y_test_lst,
                 'Predicted Share': preds_ln
                }

df_pred_ln = pd.DataFrame(ds_pred_ln).sort_values('Predicted Share', ascending=False)
# Out:
# Mean squared error: 0.494
# R2 score: 0.660

# %%
df_pred_ln
# Out:
#    Actual Rank                 Player  Actual Share  Predicted Share
# 0            1           Nikola Jokić      2.763349         1.262613
# 2            3  Giannis Antetokounmpo      1.683603         1.051370
# 1            2            Joel Embiid      2.111645         0.947925
# 4            5            Luka Dončić     -0.047848         0.422125
# 3            4           Devin Booker      0.222089         0.159453
# 5            6           Jayson Tatum     -0.445040         0.120755
# 6            7              Ja Morant     -0.572296         0.086420
# 7            8          Stephen Curry     -0.595434        -0.145574
# 8            9             Chris Paul     -0.603146        -0.205399
# 10         10T           LeBron James     -0.607002        -0.397371
# 9          10T          DeMar DeRozan     -0.607002        -0.398885

# %%
from sklearn.linear_model import LinearRegression

model_ln = LinearRegression()


model_ln, mvp_race_lst_ln, summary_ln = run_model(model_ln,
                                                  full_historical_data_pg_reduced,
                                                  years,
                                                  scaling = True
                                                 )
    
mse_ln = np.mean(summary_ln['MSE score'].values)
R2_ln = np.mean(summary_ln['R2 score'].values)
accuracy_ln = (summary_ln['Result'] == 'Right').sum() / len(years)

# %%
accuracy_ln
# Out:
# 0.5714285714285714

# %%
DNN_model = keras_model(n1=40,
                       n2=60,
                       optimizer=keras.optimizers.SGD,
                       learn_rate=0.15,
                       dropout=0.15)
    
model_DNN, mvp_race_lst_DNN, summary_DNN = run_model(DNN_model,
                                                  full_historical_data_pg_reduced,
                                                  years,
                                                  scaling = True,
                                                  NN = True,
                                                  epochs = 80,
                                                  batch_size= 40
                                                 )

mse_DNN = np.mean(summary_DNN['MSE score'].values)
R2_DNN = np.mean(summary_DNN['R2 score'].values)
accuracy_DNN = (summary_DNN['Result'] == 'Right').sum() / len(years)
# Out:
# 2022-09-11 14:15:08.204045: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
# 1/1 [==============================] - 0s 24ms/step

# %%
summary_DNN
# Out:
#     Year             Actual MVP          Predicted MVP  MSE score  R2 score  \
# 0   1980    Kareem Abdul-Jabbar          Julius Erving   0.027942  0.308526
# 1   1981          Julius Erving          Julius Erving   0.009357  0.667878
# 2   1982           Moses Malone             Larry Bird   0.009734  0.707500
# 3   1983           Moses Malone           Moses Malone   0.005178  0.896497
# 4   1984             Larry Bird             Larry Bird   0.021015  0.604212
# 5   1985             Larry Bird             Larry Bird   0.003502  0.920243
# 6   1986             Larry Bird             Larry Bird   0.009014  0.846973
# 7   1987          Magic Johnson          Magic Johnson   0.011281  0.824729
# 8   1988         Michael Jordan         Michael Jordan   0.008379  0.878361
# 9   1989          Magic Johnson          Magic Johnson   0.002837  0.948526
# 10  1990          Magic Johnson          Magic Johnson   0.020607  0.685895
# ...

# %% [markdown]
# ## Training

# %%
RF_model = RandomForestRegressor(n_estimators = 46,
                                max_depth = 17,
                                min_samples_leaf = 3,
                                min_samples_split = 2,
                                random_state = 42
                                )

model_RF, mvp_race_lst_RF, summary_RF = run_model(RF_model,
                                                  full_historical_data_pg_reduced,
                                                  years
                                                 )
    
mse_RF = np.mean(summary_RF['MSE score'].values)
R2_RF = np.mean(summary_RF['R2 score'].values)
accuracy_RF = (summary_RF['Result'] == 'Right').sum() / len(years)

# %%
summary_RF
# Out:
#     Year             Actual MVP          Predicted MVP  MSE score  R2 score  \
# 0   1980    Kareem Abdul-Jabbar          Julius Erving   0.024239  0.400154
# 1   1981          Julius Erving          Julius Erving   0.009070  0.678073
# 2   1982           Moses Malone             Larry Bird   0.018134  0.455113
# 3   1983           Moses Malone           Moses Malone   0.025492  0.490400
# 4   1984             Larry Bird             Larry Bird   0.030242  0.430426
# 5   1985             Larry Bird             Larry Bird   0.006583  0.850071
# 6   1986             Larry Bird             Larry Bird   0.017693  0.699640
# 7   1987          Magic Johnson          Magic Johnson   0.012702  0.802659
# 8   1988         Michael Jordan         Michael Jordan   0.018006  0.738615
# 9   1989          Magic Johnson         Michael Jordan   0.008260  0.850147
# 10  1990          Magic Johnson          Magic Johnson   0.022801  0.652451
# ...

# %%
x_train_pg = full_historical_data_pg_reduced.drop(['Rank','Player', 'Age', 'Tm', 'Share', 'Year'],
                                                  axis=1
                                                 )
y_train_pg = full_historical_data_pg_reduced['Share']

# %%
def data_prep(train_data, test_data, feats, target = 'Share', scaling = False):
    
    train_df = train_data.copy()
    test_df = test_data.copy()
    
    feats_all = list(feats) #+ [target]
    
    if scaling == True:
        features_train = train_df[feats_all]
        features_test = test_df[feats_all]
        scaler = StandardScaler()
        train_scaled = scaler.fit_transform(features_train)
        test_scaled = scaler.transform(features_test)
        train_df[feats_all] = train_scaled
        test_df[feats_all] = test_scaled
        
    x_train = train_df.drop(target, axis=1)
    y_train = train_df[target]
    x_test = test_df.drop(target, axis=1)
    y_test = test_df[target]
    
    return x_train, y_train, x_test, y_test

# %%
feat_importance_RF = []
cols = x_train_pg.columns.values
for model in model_RF:
    feat_scores = model.feature_importances_
    feat_importance_RF.append(feat_scores)
    
feat_df_RF = pd.DataFrame(feat_importance_RF, columns=cols)
feat_df_avg_RF = feat_df_RF.mean()
feat_df_avg_RF.sort_values(ascending = False)
# Out:
# VORP     0.277669
# PER      0.199178
# W/L%     0.173191
# WS/48    0.059696
# OBPM     0.045832
# TOV      0.044722
# PTS      0.036532
# DWS      0.036472
# BPM      0.030057
# OWS      0.020803
# USG%     0.020329
# FTr      0.020115
# DRB%     0.020002
# TS%      0.015403
# dtype: float64

# %%
plot_scores(feat_df_avg_RF,
            figsize=(8,8),
            title = 'Feature Importance: RF'
            )

# %%
XGB_model = XGBRegressor(n_estimators = 43,
                        learning_rate = 0.16,
                        max_depth = 3
                        )
            
model_XGB, mvp_race_lst_XGB, summary_XGB = run_model(XGB_model,
                                                     full_historical_data_pg_reduced,
                                                     years
                                                    )
    
mse_XGB = np.mean(summary_XGB['MSE score'].values)
R2_XGB = np.mean(summary_XGB['R2 score'].values)
accuracy_XGB = (summary_XGB['Result'] == 'Right').sum() / len(years)

# %%
summary_XGB
# Out:
#     Year             Actual MVP          Predicted MVP  MSE score  R2 score  \
# 0   1980    Kareem Abdul-Jabbar    Kareem Abdul-Jabbar   0.017850  0.558262
# 1   1981          Julius Erving          Julius Erving   0.009834  0.650928
# 2   1982           Moses Malone             Larry Bird   0.016914  0.491783
# 3   1983           Moses Malone           Moses Malone   0.022170  0.556808
# 4   1984             Larry Bird             Larry Bird   0.030856  0.418862
# 5   1985             Larry Bird             Larry Bird   0.006292  0.856708
# 6   1986             Larry Bird             Larry Bird   0.013127  0.777158
# 7   1987          Magic Johnson          Magic Johnson   0.017854  0.722612
# 8   1988         Michael Jordan         Michael Jordan   0.016796  0.756177
# 9   1989          Magic Johnson          Magic Johnson   0.007763  0.859157
# 10  1990          Magic Johnson          Magic Johnson   0.034428  0.475218
# ...

# %%
feat_importance_XGB = []
cols = x_train_pg.columns.values
for model in model_XGB:
    feat_scores = model.feature_importances_
    feat_importance_XGB.append(feat_scores)
    
feat_df_XGB = pd.DataFrame(feat_importance_XGB, columns=cols)
feat_df_avg_XGB = feat_df_XGB.mean()
feat_df_avg_XGB.sort_values(ascending = False)
# Out:
# VORP     0.397069
# PER      0.221387
# W/L%     0.093090
# TOV      0.038492
# WS/48    0.037133
# USG%     0.035964
# DWS      0.031857
# OBPM     0.031439
# BPM      0.029320
# PTS      0.025358
# OWS      0.021732
# FTr      0.013790
# DRB%     0.011736
# TS%      0.011634
# dtype: float32

# %%
plot_scores(feat_df_avg_XGB,
            figsize=(8,8),
            title = 'Feature Importance: XGB'
            )

# %% [markdown]
# ## Predictions

# %%
linear = LinearRegression()

# %%
best_NN = keras_model(n1=40,
                      n2=60,
                      optimizer=keras.optimizers.SGD,
                      learn_rate=0.15,
                      dropout=0.15
                     )

x_train_all, y_train, x_test_all, y_test = data_prep(full_historical_data_pg_reduced,
                                             full_prediction_data_pg_reduced,
                                             feats_pg,
                                             scaling=True
                                            )

# %%
x_train = x_train_all.drop(['Rank', 'Player', 'Tm', 'Year', 'Age'], axis=1)
x_test = x_test_all.drop(['Rank', 'Player', 'Tm', 'Year', 'Age'], axis=1)

best_NN.fit(x_train, y_train, epochs=50, batch_size=50, verbose=0)

# %%
rank = x_test_all['Rank'].tolist()
names = x_test_all['Player'].tolist()
preds_NN = best_NN.predict(x_test)
preds_NN = preds_NN.tolist()
y_test_lst = y_test.tolist()
#y_test_lst = full_prediction_data_pg_reduced['Share'].tolist()
print("Mean squared error: %.3f" % mean_squared_error(y_test_lst, preds_NN))
print('R2 score: %.3f' % r2_score(y_test_lst, preds_NN))

ds_pred_NN = {'Actual Rank': rank,
                 'Player': names,
                 'Actual Share': y_test_lst,
                 'Predicted Share': preds_NN
                }

df_pred_NN = pd.DataFrame(ds_pred_NN).sort_values('Predicted Share', ascending=False)
# Out:
# 1/1 [==============================] - 0s 161ms/step
# Mean squared error: 0.030
# R2 score: 0.688

# %%
df_pred_NN
# Out:
#    Actual Rank                 Player  Actual Share         Predicted Share
# 0            1           Nikola Jokić         0.875    [0.6051250100135803]
# 2            3  Giannis Antetokounmpo         0.595    [0.4733537435531616]
# 1            2            Joel Embiid         0.706   [0.46537870168685913]
# 4            5            Luka Dončić         0.146    [0.3822820484638214]
# 5            6           Jayson Tatum         0.043   [0.16471613943576813]
# 3            4           Devin Booker         0.216   [0.09036776423454285]
# 6            7              Ja Morant         0.010   [0.08173443377017975]
# 7            8          Stephen Curry         0.004   [0.07826759666204453]
# 9          10T          DeMar DeRozan         0.001  [0.033808737993240356]
# 10         10T           LeBron James         0.001   [0.03295951709151268]
# 8            9             Chris Paul         0.002   [0.02949479967355728]

# %%
x_train = x_train_all.drop(['Rank', 'Player', 'Tm', 'Year', 'Age'], axis=1)
x_test = x_test_all.drop(['Rank', 'Player', 'Tm', 'Year', 'Age'], axis=1)
linear.fit(x_train, y_train)

rank = full_prediction_data_pg_reduced['Rank'].tolist()
names = full_prediction_data_pg_reduced['Player'].tolist()
preds_ln = linear.predict(x_test)
preds_ln = preds_ln.tolist()
y_test_lst = full_prediction_data_pg_reduced['Share'].tolist()
print("Mean squared error: %.3f" % mean_squared_error(y_test_lst, preds_ln))
print('R2 score: %.3f' % r2_score(y_test_lst, preds_ln))

ds_pred_ln = {'Actual Rank': rank,
                 'Player': names,
                 'Actual Share': y_test_lst,
                 'Predicted Share': preds_ln
                }

df_pred_ln = pd.DataFrame(ds_pred_ln).sort_values('Predicted Share', ascending=False)
# Out:
# Mean squared error: 0.146
# R2 score: -0.499

# %%
df_pred_ln
# Out:
#    Actual Rank                 Player  Actual Share  Predicted Share
# 0            1           Nikola Jokić         0.875         1.453101
# 2            3  Giannis Antetokounmpo         0.595         0.949127
# 1            2            Joel Embiid         0.706         0.685539
# 4            5            Luka Dončić         0.146         0.424396
# 5            6           Jayson Tatum         0.043        -0.016980
# 8            9             Chris Paul         0.002        -0.039708
# 6            7              Ja Morant         0.010        -0.107975
# 7            8          Stephen Curry         0.004        -0.206300
# 3            4           Devin Booker         0.216        -0.207479
# 10         10T           LeBron James         0.001        -0.603458
# 9          10T          DeMar DeRozan         0.001        -0.680619

# %%
best_RF = RandomForestRegressor(n_estimators=46,
                                min_samples_split=2,
                                min_samples_leaf=3,
                                max_depth=17,
                                random_state=42
                               )


best_RF.fit(x_train_pg, y_train_pg)

rank = full_prediction_data_pg_reduced['Rank'].tolist()
names = full_prediction_data_pg_reduced['Player'].tolist()
preds_pg = best_RF.predict(data_pred_pg_reduced)
preds_pg = preds_pg.tolist()
y_test_pg = full_prediction_data_pg_reduced['Share'].tolist()
print("Mean squared error: %.3f" % mean_squared_error(y_test_pg, preds_pg))
print('R2 score: %.3f' % r2_score(y_test_pg, preds_pg))

ds_pred_RF_pg = {'Actual Rank': rank,
                 'Player': names,
                 'Actual Share': y_test_pg,
                 'Predicted Share': preds_pg
                }

df_pred_RF_pg = pd.DataFrame(ds_pred_RF_pg).sort_values('Predicted Share', ascending=False)
# Out:
# Mean squared error: 0.031
# R2 score: 0.686

# %%
df_pred_RF_pg
# Out:
#    Actual Rank                 Player  Actual Share  Predicted Share
# 0            1           Nikola Jokić         0.875         0.568798
# 2            3  Giannis Antetokounmpo         0.595         0.512341
# 1            2            Joel Embiid         0.706         0.367293
# 4            5            Luka Dončić         0.146         0.279144
# 6            7              Ja Morant         0.010         0.209193
# 10         10T           LeBron James         0.001         0.177006
# 5            6           Jayson Tatum         0.043         0.140858
# 3            4           Devin Booker         0.216         0.089758
# 7            8          Stephen Curry         0.004         0.060431
# 9          10T          DeMar DeRozan         0.001         0.055698
# 8            9             Chris Paul         0.002         0.040819

# %%
best_XGB = XGBRegressor(n_estimators=43,
                        max_depth=3,
                        learning_rate = 0.16
                        )


best_XGB.fit(x_train_pg, y_train_pg)

rank = full_prediction_data_pg_reduced['Rank'].tolist()
names = full_prediction_data_pg_reduced['Player'].tolist()
preds_XGB_pg = best_XGB.predict(data_pred_pg_reduced)
preds_XGB_pg = preds_XGB_pg.tolist()
y_test_pg = full_prediction_data_pg_reduced['Share'].tolist()
print("Mean squared error: %.3f" % mean_squared_error(y_test_pg, preds_XGB_pg))
print('R2 score: %.3f' % r2_score(y_test_pg, preds_XGB_pg))

ds_pred_XGB_pg = {'Actual Rank': rank,
                 'Player': names,
                 'Actual Share': y_test_pg,
                 'Predicted Share': preds_XGB_pg
                }

df_pred_XGB_pg = pd.DataFrame(ds_pred_XGB_pg).sort_values('Predicted Share', ascending=False)
# Out:
# Mean squared error: 0.023
# R2 score: 0.766

# %%
df_pred_XGB_pg
# Out:
#    Actual Rank                 Player  Actual Share  Predicted Share
# 2            3  Giannis Antetokounmpo         0.595         0.659588
# 0            1           Nikola Jokić         0.875         0.598019
# 1            2            Joel Embiid         0.706         0.485149
# 4            5            Luka Dončić         0.146         0.346344
# 6            7              Ja Morant         0.010         0.234683
# 3            4           Devin Booker         0.216         0.174804
# 10         10T           LeBron James         0.001         0.151860
# 5            6           Jayson Tatum         0.043         0.094464
# 7            8          Stephen Curry         0.004         0.053264
# 9          10T          DeMar DeRozan         0.001         0.040206
# 8            9             Chris Paul         0.002         0.002770
